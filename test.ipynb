# %% [markdown]
# merge data

# %%
import os
import shutil

def collect_txt_files(base_path):
   # golden과 non-golden 샘플의 루트 폴더
   golden_path = os.path.join(base_path, 'golden_sample')
   non_golden_path = os.path.join(base_path, 'non_golden_sample')
   
   # golden_sample 폴더 처리
   if os.path.exists(golden_path):
       for category in os.listdir(golden_path):
           category_path = os.path.join(golden_path, category)
           if os.path.isdir(category_path):
               for file in os.listdir(category_path):
                   if file.endswith('.txt'):  # txt 파일만 처리
                       src = os.path.join(category_path, file)
                       dst = os.path.join(golden_path, file)
                       shutil.move(src, dst)  # 파일 이동

   # non_golden_sample 폴더 처리
   if os.path.exists(non_golden_path):
       for category in os.listdir(non_golden_path):
           category_path = os.path.join(non_golden_path, category)
           if os.path.isdir(category_path):
               for file in os.listdir(category_path):
                   if file.endswith('.txt'):  # txt 파일만 처리
                       src = os.path.join(category_path, file)
                       dst = os.path.join(non_golden_path, file)
                       shutil.move(src, dst)  # 파일 이동

# 사용 예시
data_path = './data'  # 실제 데이터 폴더 경로로 수정하세요
collect_txt_files(data_path)

# %%
import torch
print(torch.cuda.is_available())  # True가 나와야 함
print(torch.cuda.get_device_name(0))  # GPU 이름 출력
# Out:
# True
# NVIDIA GeForce RTX 3060

# %%
import pandas as pd
import os

def process_data(file_path):
    # 파일 읽기
    df = pd.read_csv(file_path, delimiter=',')
    
    # 열 이름 설정
    expected_columns = ['r', 'sequence', 'timestamp', 'deg', 'deg/sec', 'mA', 
                       'endpoint', 'grip/rotation', 'torque', 'force', 'ori', '#']
    
    if df.shape[1] != len(expected_columns):
        print(f"Warning: File {file_path} has {df.shape[1]} columns, expected {len(expected_columns)}")
        return None
        
    df.columns = expected_columns
    
    # 's' 행 제거하고 다시 저장
    df = df[df['r'] == 'r'].reset_index(drop=True)
    df.to_csv(file_path, index=False)
    print(f"Processed {file_path}: Removed 's' rows")

# 데이터 디렉토리 경로 설정
base_dir = "data"
golden_dir = os.path.join(base_dir, "golden_sample")
non_golden_dir = os.path.join(base_dir, "non_golden_sample")

# golden_sample 처리
print("\nProcessing golden samples...")
for file in os.listdir(golden_dir):
    if file.endswith('.txt'):
        file_path = os.path.join(golden_dir, file)
        process_data(file_path)

# non_golden_sample 처리
print("\nProcessing non-golden samples...")
for file in os.listdir(non_golden_dir):
    if file.endswith('.txt'):
        file_path = os.path.join(non_golden_dir, file)
        process_data(file_path)

print("\nAll files processed!")
# Out:
# Processing golden samples...
# Processed data\golden_sample\clock_big_10.txt: Removed 's' rows
# Processed data\golden_sample\clock_big_22.txt: Removed 's' rows
# Processed data\golden_sample\clock_big_3.txt: Removed 's' rows
# Processed data\golden_sample\clock_big_6.txt: Removed 's' rows
# Processed data\golden_sample\clock_big_7.txt: Removed 's' rows
# Processed data\golden_sample\clock_big_8.txt: Removed 's' rows
# Processed data\golden_sample\clock_big_9.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_1.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_11.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_22.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_23.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_25.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_26.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_4.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_6.txt: Removed 's' rows
# Processed data\golden_sample\clock_b_9.txt: Removed 's' rows
# Processed data\golden_sample\clock_l_10.txt: Removed 's' rows
# Processed data\golden_sample\clock_l_14.txt: Removed 's' rows
# Processed data\golden_sample\clock_l_21.txt: Removed 's' rows
# Processed data\golden_sample\clock_l_22.txt: Removed 's' rows
# Processed data\golden_sample\clock_l_23.txt: Removed 's' rows
# Processed data\golden_sample\clock_l_25.txt: Removed 's' rows
# Processed data\golden_sample\clock_l_5.txt: Removed 's' rows
# Processed data\golden_sample\clock_l_6.txt: Removed 's' rows
# Processed data\golden_sample\clock_m_10.txt: Removed 's' rows
# Processed data\golden_sample\clock_m_16.txt: Removed 's' rows
# Processed data\golden_sample\clock_m_17.txt: Removed 's' rows
# Processed data\golden_sample\clock_m_18.txt: Removed 's' rows
# Processed data\golden_sample\clock_m_19.txt: Removed 's' rows
# Processed data\golden_sample\clock_m_20.txt: Removed 's' rows
# Processed data\golden_sample\clock_m_3.txt: Removed 's' rows
# Processed data\golden_sample\clock_m_6.txt: Removed 's' rows
# Processed data\golden_sample\clock_r_10.txt: Removed 's' rows
# Processed data\golden_sample\clock_r_17.txt: Removed 's' rows
# Processed data\golden_sample\clock_r_18.txt: Removed 's' rows
# Processed data\golden_sample\clock_r_23.txt: Removed 's' rows
# Processed data\golden_sample\clock_r_26.txt: Removed 's' rows
# Processed data\golden_sample\clock_r_6.txt: Removed 's' rows
# Processed data\golden_sample\clock_r_8.txt: Removed 's' rows
# Processed data\golden_sample\clock_r_9.txt: Removed 's' rows
# Processed data\golden_sample\clock_t_1.txt: Removed 's' rows
# Processed data\golden_sample\clock_t_15.txt: Removed 's' rows
# Processed data\golden_sample\clock_t_23.txt: Removed 's' rows
# Processed data\golden_sample\clock_t_24.txt: Removed 's' rows
# Processed data\golden_sample\clock_t_4.txt: Removed 's' rows
# Processed data\golden_sample\clock_t_6.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_12.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_13.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_14.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_15.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_2.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_23.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_24.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_25.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_27.txt: Removed 's' rows
# Processed data\golden_sample\counter_big_4.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_11.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_12.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_14.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_23.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_24.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_25.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_26.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_3.txt: Removed 's' rows
# Processed data\golden_sample\counter_b_8.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_10.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_13.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_15.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_16.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_24.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_25.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_26.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_27.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_28.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_3.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_4.txt: Removed 's' rows
# Processed data\golden_sample\counter_l_8.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_1.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_11.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_14.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_15.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_16.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_17.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_4.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_7.txt: Removed 's' rows
# Processed data\golden_sample\counter_m_8.txt: Removed 's' rows
# Processed data\golden_sample\counter_r_10.txt: Removed 's' rows
# Processed data\golden_sample\counter_r_18.txt: Removed 's' rows
# Processed data\golden_sample\counter_r_19.txt: Removed 's' rows
# Processed data\golden_sample\counter_r_27.txt: Removed 's' rows
# Processed data\golden_sample\counter_r_3.txt: Removed 's' rows
# Processed data\golden_sample\counter_r_5.txt: Removed 's' rows
# Processed data\golden_sample\counter_r_7.txt: Removed 's' rows
# Processed data\golden_sample\counter_r_9.txt: Removed 's' rows
# Processed data\golden_sample\counter_t_15.txt: Removed 's' rows
# Processed data\golden_sample\counter_t_20.txt: Removed 's' rows
# Processed data\golden_sample\counter_t_22.txt: Removed 's' rows
# Processed data\golden_sample\counter_t_28.txt: Removed 's' rows
# Processed data\golden_sample\counter_t_4.txt: Removed 's' rows
# Processed data\golden_sample\counter_t_6.txt: Removed 's' rows
# Processed data\golden_sample\counter_t_7.txt: Removed 's' rows
# Processed data\golden_sample\d_l_1.txt: Removed 's' rows
# Processed data\golden_sample\d_l_11.txt: Removed 's' rows
# Processed data\golden_sample\d_l_12.txt: Removed 's' rows
# Processed data\golden_sample\d_l_18.txt: Removed 's' rows
# Processed data\golden_sample\d_l_19.txt: Removed 's' rows
# Processed data\golden_sample\d_l_20.txt: Removed 's' rows
# Processed data\golden_sample\d_l_22.txt: Removed 's' rows
# Processed data\golden_sample\d_l_7.txt: Removed 's' rows
# Processed data\golden_sample\d_l_8.txt: Removed 's' rows
# Processed data\golden_sample\d_r_13.txt: Removed 's' rows
# Processed data\golden_sample\d_r_14.txt: Removed 's' rows
# Processed data\golden_sample\d_r_15.txt: Removed 's' rows
# Processed data\golden_sample\d_r_16.txt: Removed 's' rows
# Processed data\golden_sample\d_r_17.txt: Removed 's' rows
# Processed data\golden_sample\d_r_18.txt: Removed 's' rows
# Processed data\golden_sample\d_r_2.txt: Removed 's' rows
# Processed data\golden_sample\d_r_24.txt: Removed 's' rows
# Processed data\golden_sample\d_r_3.txt: Removed 's' rows
# Processed data\golden_sample\d_r_4.txt: Removed 's' rows
# Processed data\golden_sample\d_r_6.txt: Removed 's' rows
# Processed data\golden_sample\d_r_8.txt: Removed 's' rows
# Processed data\golden_sample\d_r_9.txt: Removed 's' rows
# Processed data\golden_sample\h_d_10.txt: Removed 's' rows
# Processed data\golden_sample\h_d_11.txt: Removed 's' rows
# Processed data\golden_sample\h_d_14.txt: Removed 's' rows
# Processed data\golden_sample\h_d_15.txt: Removed 's' rows
# Processed data\golden_sample\h_d_9.txt: Removed 's' rows
# Processed data\golden_sample\h_u_12.txt: Removed 's' rows
# Processed data\golden_sample\h_u_13.txt: Removed 's' rows
# Processed data\golden_sample\h_u_14.txt: Removed 's' rows
# Processed data\golden_sample\h_u_15.txt: Removed 's' rows
# Processed data\golden_sample\h_u_2.txt: Removed 's' rows
# Processed data\golden_sample\h_u_22.txt: Removed 's' rows
# Processed data\golden_sample\h_u_3.txt: Removed 's' rows
# Processed data\golden_sample\h_u_4.txt: Removed 's' rows
# Processed data\golden_sample\h_u_5.txt: Removed 's' rows
# Processed data\golden_sample\h_u_6.txt: Removed 's' rows
# Processed data\golden_sample\h_u_7.txt: Removed 's' rows
# Processed data\golden_sample\h_u_8.txt: Removed 's' rows
# Processed data\golden_sample\h_u_9.txt: Removed 's' rows
# Processed data\golden_sample\v_135_1.txt: Removed 's' rows
# Processed data\golden_sample\v_135_10.txt: Removed 's' rows
# Processed data\golden_sample\v_135_11.txt: Removed 's' rows
# Processed data\golden_sample\v_135_12.txt: Removed 's' rows
# Processed data\golden_sample\v_135_13.txt: Removed 's' rows
# Processed data\golden_sample\v_135_14.txt: Removed 's' rows
# Processed data\golden_sample\v_135_15.txt: Removed 's' rows
# Processed data\golden_sample\v_135_2.txt: Removed 's' rows
# Processed data\golden_sample\v_135_3.txt: Removed 's' rows
# Processed data\golden_sample\v_135_4.txt: Removed 's' rows
# Processed data\golden_sample\v_135_5.txt: Removed 's' rows
# Processed data\golden_sample\v_135_6.txt: Removed 's' rows
# Processed data\golden_sample\v_135_7.txt: Removed 's' rows
# Processed data\golden_sample\v_135_8.txt: Removed 's' rows
# Processed data\golden_sample\v_135_9.txt: Removed 's' rows
# Processed data\golden_sample\v_180_12.txt: Removed 's' rows
# Processed data\golden_sample\v_180_14.txt: Removed 's' rows
# Processed data\golden_sample\v_180_6.txt: Removed 's' rows
# Processed data\golden_sample\v_180_9.txt: Removed 's' rows
# Processed data\golden_sample\v_45_13.txt: Removed 's' rows
# Processed data\golden_sample\v_45_14.txt: Removed 's' rows
# Processed data\golden_sample\v_45_2.txt: Removed 's' rows
# Processed data\golden_sample\v_45_4.txt: Removed 's' rows
# Processed data\golden_sample\v_45_5.txt: Removed 's' rows
# Processed data\golden_sample\v_90_10.txt: Removed 's' rows
# Processed data\golden_sample\v_90_11.txt: Removed 's' rows
# Processed data\golden_sample\v_90_12.txt: Removed 's' rows
# Processed data\golden_sample\v_90_13.txt: Removed 's' rows
# Processed data\golden_sample\v_90_3.txt: Removed 's' rows
# Processed data\golden_sample\v_90_6.txt: Removed 's' rows
# Processed data\golden_sample\v_90_7.txt: Removed 's' rows
# Processed data\golden_sample\v_90_9.txt: Removed 's' rows
#
# Processing non-golden samples...
# Processed data\non_golden_sample\clock_big_1.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_11.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_12.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_13.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_14.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_15.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_16.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_17.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_18.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_19.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_2.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_20.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_21.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_23.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_24.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_25.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_26.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_4.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_big_5.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_10.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_12.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_13.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_14.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_15.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_16.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_17.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_18.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_19.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_2.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_20.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_21.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_24.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_3.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_5.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_7.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_b_8.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_1.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_11.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_12.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_13.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_15.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_16.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_17.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_18.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_19.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_2.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_20.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_24.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_26.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_3.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_4.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_7.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_8.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_l_9.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_1.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_11.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_12.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_13.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_14.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_15.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_2.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_21.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_22.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_23.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_24.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_25.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_4.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_5.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_7.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_8.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_m_9.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_1.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_11.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_12.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_13.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_14.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_15.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_16.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_19.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_2.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_20.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_21.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_22.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_24.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_25.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_3.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_4.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_5.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_r_7.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_10.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_11.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_12.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_13.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_14.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_16.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_17.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_18.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_19.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_2.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_20.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_21.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_22.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_25.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_26.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_3.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_5.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_7.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_8.txt: Removed 's' rows
# Processed data\non_golden_sample\clock_t_9.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_1.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_10.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_11.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_16.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_17.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_18.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_19.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_20.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_21.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_22.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_26.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_3.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_5.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_6.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_7.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_8.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_big_9.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_1.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_10.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_13.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_15.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_16.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_17.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_18.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_19.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_2.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_20.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_21.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_22.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_4.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_5.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_6.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_7.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_b_9.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_1.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_11.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_12.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_14.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_17.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_18.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_19.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_2.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_20.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_21.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_22.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_23.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_5.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_6.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_7.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_l_9.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_10.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_12.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_13.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_18.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_19.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_2.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_20.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_21.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_22.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_23.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_24.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_25.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_3.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_5.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_6.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_m_9.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_1.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_11.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_12.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_13.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_14.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_15.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_16.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_17.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_2.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_20.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_21.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_22.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_23.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_24.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_25.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_26.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_4.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_6.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_r_8.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_1.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_10.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_11.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_12.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_13.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_14.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_16.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_17.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_18.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_19.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_2.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_21.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_23.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_24.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_25.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_26.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_27.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_3.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_5.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_8.txt: Removed 's' rows
# Processed data\non_golden_sample\counter_t_9.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_10.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_13.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_14.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_15.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_16.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_17.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_2.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_21.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_3.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_4.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_5.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_6.txt: Removed 's' rows
# Processed data\non_golden_sample\d_l_9.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_1.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_10.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_11.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_12.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_19.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_20.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_21.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_22.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_23.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_5.txt: Removed 's' rows
# Processed data\non_golden_sample\d_r_7.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_1.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_12.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_13.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_16.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_17.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_18.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_19.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_2.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_20.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_3.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_4.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_5.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_6.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_7.txt: Removed 's' rows
# Processed data\non_golden_sample\h_d_8.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_1.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_10.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_11.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_16.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_17.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_18.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_19.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_20.txt: Removed 's' rows
# Processed data\non_golden_sample\h_u_21.txt: Removed 's' rows
# Processed data\non_golden_sample\v_135_16.txt: Removed 's' rows
# Processed data\non_golden_sample\v_135_17.txt: Removed 's' rows
# Processed data\non_golden_sample\v_135_18.txt: Removed 's' rows
# Processed data\non_golden_sample\v_135_19.txt: Removed 's' rows
# Processed data\non_golden_sample\v_135_20.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_1.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_10.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_11.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_13.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_15.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_16.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_17.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_18.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_19.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_2.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_20.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_3.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_4.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_5.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_7.txt: Removed 's' rows
# Processed data\non_golden_sample\v_180_8.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_1.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_10.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_11.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_12.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_15.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_16.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_17.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_18.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_19.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_20.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_3.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_6.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_7.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_8.txt: Removed 's' rows
# Processed data\non_golden_sample\v_45_9.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_1.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_14.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_15.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_16.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_17.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_18.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_19.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_2.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_20.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_21.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_22.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_4.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_5.txt: Removed 's' rows
# Processed data\non_golden_sample\v_90_8.txt: Removed 's' rows
#
# All files processed!

# %%
problem_file = "data/non_golden_sample/v_90_5.txt"
with open(problem_file, 'r') as f:
    print("First few lines of the file:")
    for i, line in enumerate(f):
        if i < 5:  # 처음 5줄만 출력
            print(line.strip())
# Out:
# First few lines of the file:
# s,0,# dh
# r,80686,1662554,4/60/0/89,0/0/0/0,0/0/0/0,518/-37/-340,0/0,-38/1760/-13686,-678/318/512,-1691/-296/-25,# dh
# r,80687,1662575,4/60/0/89,0/1/0/0,0/0/0/0,518/-37/-340,0/0,-4/1820/-13602,-658/306/514,-1691/-296/-25,# dh
# r,80688,1662602,4/60/0/89,0/1/0/0,0/0/0/0,518/-37/-340,0/0,38/1900/-13536,-636/291/510,-1691/-296/-25,# dh
# r,80689,1662621,4/60/0/89,0/0/0/0,0/0/0/0,518/-37/-340,0/0,100/2029/-13488,-622/280/508,-1691/-296/-25,# dh
